# %%
import ijson
import zipfile
import pandas as pd

# %%
def extract_itens(input_file_path, target_inst=None):
    set_of_itens = []

    with zipfile.ZipFile(input_file_path, "r") as zip_file:
        filename= zip_file.namelist()[0]
    
        with zip_file.open(filename) as json_file:
            parser = ijson.parse(json_file)

        # Inicie o parsing do JSON
            in_docs = False
            for prefix, event, value in parser:
                if in_docs:
                    if event == 'start_map':
                        doc = {}  # Inicie um novo dicionário para cada documento "docs"
                    elif event == 'end_map':
                    # Faça algo com o documento, por exemplo, imprimir ou processar
                    # i+=1
                    # if i > limit:
                    #     break
                        if target_inst!= None:
                            try:
                                if target_inst.get(doc['instacron_str']) != None:
                                    set_of_itens.append(doc)
                            except KeyError:
                                pass
                        else:
                            set_of_itens.append(doc)
                    else:
                        short_prexif = prefix.split('.')[-1]
                        if short_prexif != 'item':
                            doc[short_prexif] = value
                elif prefix == 'response.docs':
                    in_docs = True

# Certifique-se de fechar o arquivo após a leitura
    json_file.close()
    return set_of_itens

# %% [markdown]
# - id - o id do documento no Oasisbr
# - oai_identifier_str - id externo que vem do repositório de origem
# - instname_str - nome da instituição de origem
# - instacron_str - acrônimo da instituição de origem
# - network_acronym_str - acrônimo da rede de origem (pode descartar)
# - network_name_str - nome da rede origem (pode descartar)
# - title - título
# - author - autores
# - publishDate  - data da publicação
# - format - tipo de documento (article, masterThesis, doctoralThesis, …)
# - description - abstract
# - topic - keywords
# - language - idioma do documento
# - eu_rights_str_mv - tipo de acesso (openAccess, closed, …)
# - url - url externa para o documento

# %%
input_file_path="D:\\tmp\oaisis\oasisbr_5.zip"

target_inst = {
                'UFCG' : 1,
               'UEPB' : 1
            }

pd.DataFrame(extract_itens(input_file_path, target_inst=target_inst)).head(2)
# Out:
#                                       id         oai_identifier_str  \
# 0  UFCG_06f953de5632423215f2902ee1c9977f  oai:localhost:riufcg/6033
# 1  UFCG_1f3af7882a45950655b4fb799ea6aa22  oai:localhost:riufcg/6034
#
#   network_acronym_str                                   network_name_str  \
# 0                UFCG  Biblioteca Digital de Teses e Dissertações da ...
# 1                UFCG  Biblioteca Digital de Teses e Dissertações da ...
#
#                                                title author  topic  \
# 0  O uso da iconografia no ensino de história: um...   None    NaN
# 1  Usos sociais da escrita por alunos de turmas d...   None    NaN
#
#                                          description publishDate format   url  \
# 0  Esta pesquisa centra-se no estudo da iconograf...        None   None  None
# 1  A presente investigação tem como foco a anális...        None   None  None
#
#    language eu_rights_str_mv                                   instname_str  \
# 0       NaN             None  Universidade Federal de Campina Grande (UFCG)
# 1       NaN             None  Universidade Federal de Campina Grande (UFCG)
#
#   instacron_str  docs
# 0          UFCG   NaN
# 1          UFCG   NaN

# %%
input_path="D:\\tmp\oaisis\\"
file_list = ['oasisbr_1.zip','oasisbr_2.zip','oasisbr_3.zip','oasisbr_4.zip','oasisbr_5.zip']

target_inst = {
               'UEPB' : 1
}

output=[]

for i in file_list:
    input_file_path = input_path + i
    out_local = extract_itens(input_file_path, target_inst=target_inst)
    output = output + out_local

# %%
uepb = pd.DataFrame(output)
# Out:
#                                            id  \
# 0       UEPB_b6a3d244e3fe58f8e05b4bac84daec30
# 1       UEPB_4f4883e23034abb8b2a696164c641a55
# 2       UEPB_fe3bdcee383cdc0a82669c88bc9ee49e
# 3       UEPB_95fc6a545b54d41af8b6b43f57db7f81
# 4       UEPB_53f3ef4940575edac02278b888f99cff
# ...                                       ...
# 2396  UEPB-3_f6740ee51eb3259f45cb31ef4944e675
# 2397  UEPB-3_f4fe1a5d899e39ead7034cffb9944484
# 2398  UEPB-3_b291c76aa9bcc137e99b0598f0f1ffc1
# 2399  UEPB-3_351da818f75adb708ab4a366761cda16
# 2400  UEPB-3_0430118b105b6a020777593ebc9aac4d
#
#                              oai_identifier_str network_acronym_str  \
# 0             oai:tede.bc.uepb.edu.br:tede/2995                UEPB
# 1             oai:tede.bc.uepb.edu.br:tede/2996                UEPB
# 2             oai:tede.bc.uepb.edu.br:tede/2997                UEPB
# 3             oai:tede.bc.uepb.edu.br:tede/2999                UEPB
# 4             oai:tede.bc.uepb.edu.br:tede/3000                UEPB
# ...                                         ...                 ...
# 2396  oai:ojs3.revista.uepb.edu.br:article/1376              UEPB-3
# 2397  oai:ojs3.revista.uepb.edu.br:article/1377              UEPB-3
# 2398  oai:ojs3.revista.uepb.edu.br:article/1378              UEPB-3
# 2399  oai:ojs3.revista.uepb.edu.br:article/1379              UEPB-3
# 2400  oai:ojs3.revista.uepb.edu.br:article/1380              UEPB-3
#
#                                        network_name_str  \
# 0     Biblioteca Digital de Teses e Dissertações da ...
# 1     Biblioteca Digital de Teses e Dissertações da ...
# 2     Biblioteca Digital de Teses e Dissertações da ...
# 3     Biblioteca Digital de Teses e Dissertações da ...
# 4     Biblioteca Digital de Teses e Dissertações da ...
# ...                                                 ...
# 2396            Revista de Estudos Internacionais (REI)
# 2397            Revista de Estudos Internacionais (REI)
# 2398            Revista de Estudos Internacionais (REI)
# 2399            Revista de Estudos Internacionais (REI)
# 2400            Revista de Estudos Internacionais (REI)
#
#                                                   title author  topic  \
# 0     Dust of ideas in the wind ou como pequenos grã...   None    NaN
# 1     Paradiplomacia no Brasil: uma abordagem sobre ...   None    NaN
# 2     Um big brother global? os programas de vigilân...   None    NaN
# 3     Um eixo problemático: as relações sino-sudanes...   None    NaN
# 4     A flexibilização do Acordo TRIPS e a necessida...   None    NaN
# ...                                                 ...    ...    ...
# 2396  MÍDIAS SOCIAIS E FAKE NEWS: DESINFORMAÇÃO COMO...   None    NaN
# 2397  IMPRENSA E POLÍTICA EXTERNA EM TEMPOS DE ABERT...   None    NaN
# 2398  A GRANDE IMPRENSA COMO CONTRAPODER EM POLÍTICA...   None    NaN
# 2399  OS TWEETS DE BOLSONARO E A COBERTURA DO THE NE...   None    NaN
# 2400  O CANAL DE NOTÍCIA RT EN ESPAÑOL NO YOUTUBE: A...   None    NaN
#
#                                             description publishDate format  \
# 0     The research aimed to screen for evidence of t...        None   None
# 1     The contemporary International Society compris...        None   None
# 2     The increasing use of cyberspace in Internatio...        None   None
# 3     This master thesis presents the relations betw...        None   None
# 4     The global transformations occurring in modern...        None   None
# ...                                                 ...         ...    ...
# 2396  As mídias sociais têm sido cada vez mais utili...        None   None
# 2397  Em novembro de 1975, o Brasil foi o primeiro E...        None   None
# 2398  O artigo analisa os posicionamentos editoriais...        None   None
# 2399  Este artigo busca contrapor e analisar os post...        None   None
# 2400  Este artigo analisa a cobertura jornalística d...        None   None
#
#        url  language eu_rights_str_mv  \
# 0     None       NaN             None
# 1     None       NaN             None
# 2     None       NaN             None
# 3     None       NaN             None
# 4     None       NaN             None
# ...    ...       ...              ...
# 2396  None       NaN             None
# 2397  None       NaN             None
# 2398  None       NaN             None
# 2399  None       NaN             None
# 2400  None       NaN             None
#
#                                  instname_str instacron_str
# 0     Universidade Estadual da Paraíba (UEPB)          UEPB
# 1     Universidade Estadual da Paraíba (UEPB)          UEPB
# 2     Universidade Estadual da Paraíba (UEPB)          UEPB
# 3     Universidade Estadual da Paraíba (UEPB)          UEPB
# 4     Universidade Estadual da Paraíba (UEPB)          UEPB
# ...                                       ...           ...
# 2396  Universidade Estadual da Paraíba (UEPB)          UEPB
# 2397  Universidade Estadual da Paraíba (UEPB)          UEPB
# 2398  Universidade Estadual da Paraíba (UEPB)          UEPB
# 2399  Universidade Estadual da Paraíba (UEPB)          UEPB
# 2400  Universidade Estadual da Paraíba (UEPB)          UEPB
#
# [2401 rows x 15 columns]

# %% [markdown]
# # oai query

# %% [markdown]
# http://harvester.ibict.br:8092/request?verb=GetRecord&identifier=oai:periodicos.ufsc.br:article/26431&metadataPrefix=xoai
#
#
# ```
# http://harvester.ibict.br:8092/request?verb=GetRecord&identifier= + id + &metadataPrefix=xoai
# ```

# %%
import requests

# URL do servidor OAI
oai_base_url = 'http://example.com/oai-pmh-server'

# Identificador que você deseja recuperar
identifier = 'oai:periodicos.ufsc.br:article/26431'

# Parâmetros da consulta
params = {
    'verb': 'GetRecord',  # A ação para recuperar um registro
    'metadataPrefix': 'oai_dc',  # O formato de metadados desejado
    'identifier': identifier  # O identificador único do registro
}

# Realizar a solicitação HTTP
response = requests.get(oai_base_url, params=params)

if response.status_code == 200:
    # O servidor respondeu com sucesso, e você pode acessar os metadados da resposta
    oai_metadata = response.content  # Isso contém os metadados do registro no formato especificado (neste caso, Dublin Core)

    # Agora você pode processar os metadados como desejado
    print(oai_metadata)
else:
    # Lidar com possíveis erros
    print("Erro na solicitação OAI-PMH. Código de status:", response.status_code)
    print(response.text)  # Isso pode conter informações de erro do servidor

# %%
user_to_repos = {}

with zipfile.ZipFile("./data/drug-event-Q4-0001-of-0013.json.zip", "r") as z:


with open("large-file.json", "rb") as f:
    for record in ijson.items(f, "item"):
        user = record["actor"]["login"]
        repo = record["repo"]["name"]
        if user not in user_to_repos:
            user_to_repos[user] = set()
        user_to_repos[user].add(repo)
